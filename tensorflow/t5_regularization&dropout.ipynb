# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.datasets import cifar10

# %%
(x_train,y_train),(x_test,y_test) = cifar10.load_data()
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
def my_model():
    inputs = keras.Input(shape=(32,32,3))
    x = layers.Conv2D(32,3,padding='same',kernel_regularizer=regularizers.l2(0.01))(inputs)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(64,3,padding='same',kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.Conv2D(128,3,padding='same',kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64,activation='relu',kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(10)(x)
    model = keras.Model(inputs=inputs,outputs=outputs)
    return model

# %%
model = my_model()

model.compile(
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
optimizer = keras.optimizers.Adam(lr=3e-4),
metrics = ['accuracy'])

model.fit(x_train,y_train,batch_size=64,epochs=150,verbose=2)
model.evaluate(x_test,y_test,batch_size=64,verbose=2)
# Out:
# Epoch 1/150
# 782/782 - 12s - loss: 2.9935 - accuracy: 0.2700
# Epoch 2/150
# 782/782 - 11s - loss: 2.0071 - accuracy: 0.3329
# Epoch 3/150
# 782/782 - 10s - loss: 1.8032 - accuracy: 0.3890
# Epoch 4/150
# 782/782 - 11s - loss: 1.6229 - accuracy: 0.4548
# Epoch 5/150
# 782/782 - 11s - loss: 1.5281 - accuracy: 0.4918
# Epoch 6/150
# 782/782 - 11s - loss: 1.4697 - accuracy: 0.5239
# Epoch 7/150
# 782/782 - 11s - loss: 1.4408 - accuracy: 0.5373
# Epoch 8/150
# 782/782 - 11s - loss: 1.4186 - accuracy: 0.5469
# Epoch 9/150
# 782/782 - 11s - loss: 1.4023 - accuracy: 0.5556
# Epoch 10/150
# 782/782 - 11s - loss: 1.3813 - accuracy: 0.5604
# Epoch 11/150
# 782/782 - 10s - loss: 1.3656 - accuracy: 0.5728
# Epoch 12/150
# 782/782 - 10s - loss: 1.3591 - accuracy: 0.5733
# Epoch 13/150
# 782/782 - 11s - loss: 1.3435 - accuracy: 0.5778
# Epoch 14/150
# 782/782 - 10s - loss: 1.3371 - accuracy: 0.5827
# Epoch 15/150
# 782/782 - 10s - loss: 1.3295 - accuracy: 0.5880
# Epoch 16/150
# 782/782 - 10s - loss: 1.3155 - accuracy: 0.5927
# Epoch 17/150
# 782/782 - 10s - loss: 1.3172 - accuracy: 0.5937
# Epoch 18/150
# 782/782 - 10s - loss: 1.3002 - accuracy: 0.6003
# Epoch 19/150
# 782/782 - 10s - loss: 1.2968 - accuracy: 0.6034
# Epoch 20/150
# 782/782 - 10s - loss: 1.2849 - accuracy: 0.6050
# Epoch 21/150
# 782/782 - 10s - loss: 1.2803 - accuracy: 0.6110
# Epoch 22/150
# 782/782 - 10s - loss: 1.2710 - accuracy: 0.6107
# Epoch 23/150
# 782/782 - 10s - loss: 1.2680 - accuracy: 0.6132
# Epoch 24/150
# 782/782 - 11s - loss: 1.2671 - accuracy: 0.6167
# Epoch 25/150
# 782/782 - 11s - loss: 1.2545 - accuracy: 0.6198
# Epoch 26/150
# 782/782 - 10s - loss: 1.2508 - accuracy: 0.6214
# Epoch 27/150
# 782/782 - 10s - loss: 1.2378 - accuracy: 0.6273
# Epoch 28/150
# 782/782 - 10s - loss: 1.2381 - accuracy: 0.6294
# Epoch 29/150
# 782/782 - 10s - loss: 1.2370 - accuracy: 0.6264
# Epoch 30/150
# 782/782 - 11s - loss: 1.2301 - accuracy: 0.6314
# Epoch 31/150
# 782/782 - 10s - loss: 1.2299 - accuracy: 0.6309
# Epoch 32/150
# 782/782 - 10s - loss: 1.2196 - accuracy: 0.6360
# Epoch 33/150
# 782/782 - 10s - loss: 1.2155 - accuracy: 0.6362
# Epoch 34/150
# 782/782 - 10s - loss: 1.2122 - accuracy: 0.6376
# Epoch 35/150
# 782/782 - 10s - loss: 1.2095 - accuracy: 0.6385
# Epoch 36/150
# 782/782 - 10s - loss: 1.2048 - accuracy: 0.6419
# Epoch 37/150
# 782/782 - 10s - loss: 1.2025 - accuracy: 0.6430
# Epoch 38/150
# 782/782 - 10s - loss: 1.1943 - accuracy: 0.6466
# Epoch 39/150
# 782/782 - 11s - loss: 1.1935 - accuracy: 0.6490
# Epoch 40/150
# 782/782 - 10s - loss: 1.1911 - accuracy: 0.6490
# Epoch 41/150
# 782/782 - 11s - loss: 1.1872 - accuracy: 0.6491
# Epoch 42/150
# 782/782 - 11s - loss: 1.1781 - accuracy: 0.6542
# Epoch 43/150
# 782/782 - 11s - loss: 1.1809 - accuracy: 0.6538
# Epoch 44/150
# 782/782 - 11s - loss: 1.1690 - accuracy: 0.6616
# Epoch 45/150
# 782/782 - 11s - loss: 1.1868 - accuracy: 0.6513
# Epoch 46/150
# 782/782 - 10s - loss: 1.1648 - accuracy: 0.6618
# Epoch 47/150
# 782/782 - 10s - loss: 1.1740 - accuracy: 0.6573
# Epoch 48/150
# 782/782 - 10s - loss: 1.1643 - accuracy: 0.6649
# Epoch 49/150
# 782/782 - 10s - loss: 1.1593 - accuracy: 0.6636
# Epoch 50/150
# 782/782 - 10s - loss: 1.1564 - accuracy: 0.6639
# Epoch 51/150
# 782/782 - 10s - loss: 1.1483 - accuracy: 0.6681
# Epoch 52/150
# 782/782 - 11s - loss: 1.1456 - accuracy: 0.6706
# Epoch 53/150
# 782/782 - 10s - loss: 1.1456 - accuracy: 0.6722
# Epoch 54/150
# 782/782 - 10s - loss: 1.1482 - accuracy: 0.6703
# Epoch 55/150
# 782/782 - 10s - loss: 1.1450 - accuracy: 0.6725
# Epoch 56/150
# 782/782 - 10s - loss: 1.1310 - accuracy: 0.6768
# Epoch 57/150
# 782/782 - 10s - loss: 1.1365 - accuracy: 0.6748
# Epoch 58/150
# 782/782 - 11s - loss: 1.1319 - accuracy: 0.6769
# Epoch 59/150
# 782/782 - 10s - loss: 1.1308 - accuracy: 0.6789
# Epoch 60/150
# 782/782 - 11s - loss: 1.1267 - accuracy: 0.6810
# Epoch 61/150
# 782/782 - 11s - loss: 1.1249 - accuracy: 0.6809
# Epoch 62/150
# 782/782 - 11s - loss: 1.1267 - accuracy: 0.6821
# Epoch 63/150
# 782/782 - 10s - loss: 1.1265 - accuracy: 0.6837
# Epoch 64/150
# 782/782 - 10s - loss: 1.1244 - accuracy: 0.6855
# Epoch 65/150
# 782/782 - 10s - loss: 1.1212 - accuracy: 0.6841
# Epoch 66/150
# 782/782 - 10s - loss: 1.1218 - accuracy: 0.6882
# Epoch 67/150
# 782/782 - 10s - loss: 1.1142 - accuracy: 0.6901
# Epoch 68/150
# 782/782 - 10s - loss: 1.1072 - accuracy: 0.6916
# Epoch 69/150
# 782/782 - 11s - loss: 1.1054 - accuracy: 0.6945
# Epoch 70/150
# 782/782 - 10s - loss: 1.0993 - accuracy: 0.6971
# Epoch 71/150
# 782/782 - 10s - loss: 1.1015 - accuracy: 0.6985
# Epoch 72/150
# 782/782 - 11s - loss: 1.0960 - accuracy: 0.6993
# Epoch 73/150
# 782/782 - 11s - loss: 1.0939 - accuracy: 0.7006
# Epoch 74/150
# 782/782 - 11s - loss: 1.0924 - accuracy: 0.7028
# Epoch 75/150
# 782/782 - 10s - loss: 1.0867 - accuracy: 0.7050
# Epoch 76/150
# 782/782 - 11s - loss: 1.0863 - accuracy: 0.7041
# Epoch 77/150
# 782/782 - 11s - loss: 1.0880 - accuracy: 0.7044
# Epoch 78/150
# 782/782 - 11s - loss: 1.0921 - accuracy: 0.7050
# Epoch 79/150
# 782/782 - 11s - loss: 1.0776 - accuracy: 0.7116
# Epoch 80/150
# 782/782 - 11s - loss: 1.0839 - accuracy: 0.7100
# Epoch 81/150
# 782/782 - 11s - loss: 1.0793 - accuracy: 0.7110
# Epoch 82/150
# 782/782 - 11s - loss: 1.0755 - accuracy: 0.7131
# Epoch 83/150
# 782/782 - 10s - loss: 1.0814 - accuracy: 0.7095
# Epoch 84/150
# 782/782 - 10s - loss: 1.0705 - accuracy: 0.7136
# Epoch 85/150
# 782/782 - 10s - loss: 1.0753 - accuracy: 0.7148
# Epoch 86/150
# 782/782 - 11s - loss: 1.0731 - accuracy: 0.7141
# Epoch 87/150
# 782/782 - 10s - loss: 1.0692 - accuracy: 0.7167
# Epoch 88/150
# 782/782 - 10s - loss: 1.0742 - accuracy: 0.7156
# Epoch 89/150
# 782/782 - 10s - loss: 1.0706 - accuracy: 0.7162
# Epoch 90/150
# 782/782 - 10s - loss: 1.0703 - accuracy: 0.7150
# Epoch 91/150
# 782/782 - 10s - loss: 1.0636 - accuracy: 0.7184
# Epoch 92/150
# 782/782 - 10s - loss: 1.0658 - accuracy: 0.7189
# Epoch 93/150
# 782/782 - 10s - loss: 1.0613 - accuracy: 0.7219
# Epoch 94/150
# 782/782 - 10s - loss: 1.0590 - accuracy: 0.7251
# Epoch 95/150
# 782/782 - 10s - loss: 1.0607 - accuracy: 0.7232
# Epoch 96/150
# 782/782 - 10s - loss: 1.0599 - accuracy: 0.7222
# Epoch 97/150
# 782/782 - 10s - loss: 1.0537 - accuracy: 0.7263
# Epoch 98/150
# 782/782 - 10s - loss: 1.0535 - accuracy: 0.7259
# Epoch 99/150
# 782/782 - 10s - loss: 1.0538 - accuracy: 0.7247
# Epoch 100/150
# 782/782 - 10s - loss: 1.0577 - accuracy: 0.7275
# Epoch 101/150
# 782/782 - 10s - loss: 1.0503 - accuracy: 0.7268
# Epoch 102/150
# 782/782 - 10s - loss: 1.0496 - accuracy: 0.7286
# Epoch 103/150
# 782/782 - 10s - loss: 1.0499 - accuracy: 0.7277
# Epoch 104/150
# 782/782 - 11s - loss: 1.0458 - accuracy: 0.7298
# Epoch 105/150
# 782/782 - 11s - loss: 1.0418 - accuracy: 0.7312
# Epoch 106/150
# 782/782 - 11s - loss: 1.0474 - accuracy: 0.7290
# Epoch 107/150
# 782/782 - 10s - loss: 1.0525 - accuracy: 0.7306
# Epoch 108/150
# 782/782 - 11s - loss: 1.0450 - accuracy: 0.7307
# Epoch 109/150
# 782/782 - 11s - loss: 1.0470 - accuracy: 0.7326
# Epoch 110/150
# 782/782 - 11s - loss: 1.0488 - accuracy: 0.7304
# Epoch 111/150
# 782/782 - 11s - loss: 1.0508 - accuracy: 0.7284
# Epoch 112/150
# 782/782 - 11s - loss: 1.0468 - accuracy: 0.7317
# Epoch 113/150
# 782/782 - 11s - loss: 1.0384 - accuracy: 0.7345
# Epoch 114/150
# 782/782 - 11s - loss: 1.0270 - accuracy: 0.7420
# Epoch 115/150
# 782/782 - 11s - loss: 1.0394 - accuracy: 0.7343
# Epoch 116/150
# 782/782 - 11s - loss: 1.0364 - accuracy: 0.7375
# Epoch 117/150
# 782/782 - 11s - loss: 1.0367 - accuracy: 0.7366
# Epoch 118/150
# 782/782 - 11s - loss: 1.0426 - accuracy: 0.7359
# Epoch 119/150
# 782/782 - 11s - loss: 1.0276 - accuracy: 0.7401
# Epoch 120/150
# 782/782 - 10s - loss: 1.0386 - accuracy: 0.7380
# Epoch 121/150
# 782/782 - 11s - loss: 1.0442 - accuracy: 0.7359
# Epoch 122/150
# 782/782 - 11s - loss: 1.0352 - accuracy: 0.7395
# Epoch 123/150
# 782/782 - 11s - loss: 1.0285 - accuracy: 0.7387
# Epoch 124/150
# 782/782 - 11s - loss: 1.0381 - accuracy: 0.7376
# Epoch 125/150
# 782/782 - 11s - loss: 1.0399 - accuracy: 0.7374
# Epoch 126/150
# 782/782 - 11s - loss: 1.0257 - accuracy: 0.7429
# Epoch 127/150
# 782/782 - 11s - loss: 1.0339 - accuracy: 0.7409
# Epoch 128/150
# 782/782 - 11s - loss: 1.0307 - accuracy: 0.7408
# Epoch 129/150
# 782/782 - 11s - loss: 1.0340 - accuracy: 0.7436
# Epoch 130/150
# 782/782 - 10s - loss: 1.0406 - accuracy: 0.7398
# Epoch 131/150
# 782/782 - 11s - loss: 1.0252 - accuracy: 0.7451
# Epoch 132/150
# 782/782 - 10s - loss: 1.0383 - accuracy: 0.7423
# Epoch 133/150
# 782/782 - 11s - loss: 1.0316 - accuracy: 0.7409
# Epoch 134/150
# 782/782 - 11s - loss: 1.0336 - accuracy: 0.7449
# Epoch 135/150
# 782/782 - 11s - loss: 1.0359 - accuracy: 0.7428
# Epoch 136/150
# 782/782 - 11s - loss: 1.0219 - accuracy: 0.7470
# Epoch 137/150
# 782/782 - 11s - loss: 1.0338 - accuracy: 0.7436
# Epoch 138/150
# 782/782 - 10s - loss: 1.0243 - accuracy: 0.7451
# Epoch 139/150
# 782/782 - 11s - loss: 1.0361 - accuracy: 0.7434
# Epoch 140/150
# 782/782 - 10s - loss: 1.0331 - accuracy: 0.7426
# Epoch 141/150
# 782/782 - 11s - loss: 1.0245 - accuracy: 0.7466
# Epoch 142/150
# 782/782 - 10s - loss: 1.0349 - accuracy: 0.7448
# Epoch 143/150
# 782/782 - 11s - loss: 1.0209 - accuracy: 0.7485
# Epoch 144/150
# 782/782 - 11s - loss: 1.0220 - accuracy: 0.7469
# Epoch 145/150
# 782/782 - 10s - loss: 1.0239 - accuracy: 0.7474
# Epoch 146/150
# 782/782 - 11s - loss: 1.0234 - accuracy: 0.7476
# Epoch 147/150
# 782/782 - 11s - loss: 1.0234 - accuracy: 0.7487
# Epoch 148/150
# 782/782 - 11s - loss: 1.0237 - accuracy: 0.7507
# Epoch 149/150
# 782/782 - 11s - loss: 1.0244 - accuracy: 0.7477
# Epoch 150/150
# 782/782 - 11s - loss: 1.0205 - accuracy: 0.7480
# 157/157 - 1s - loss: 1.2828 - accuracy: 0.7024
# [1.2827558517456055, 0.7024000287055969]
